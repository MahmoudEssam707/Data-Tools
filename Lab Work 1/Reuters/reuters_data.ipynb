# %%
# Import necessary libraries
import pandas as pd
from tkinter import filedialog

# %%
def wrangle(reuters_path):
    # Reading Data
    reuters_data =pd.read_csv(reuters_path)
    return reuters_data

# %%
# Load reuters dataset
file_path = filedialog.askopenfilename()
reuters_data = wrangle(reuters_path=file_path)
reuters_data
# Out:
#       REUTERS TOPICS   TOPICS  \
# 0                YES    cocoa
# 1                YES    grain
# 2                YES  veg-oil
# 3                YES     none
# 4                YES     earn
# ...              ...      ...
# 13146            YES     earn
# 13147            YES    trade
# 13148            YES    crude
# 13149            YES      acq
# 13150            YES      acq
#
#                                                    TITLE  \
# 0                                     BAHIA COCOA REVIEW
# 1       NATIONAL AVERAGE PRICES FOR FARMER-OWNED RESERVE
# 2          ARGENTINE 1986/87 GRAIN/OILSEED REGISTRATIONS
# 3                      USX <X> DEBT DOWGRADED BY MOODY'S
# 4            CHAMPION PRODUCTS <CH> APPROVES STOCK SPLIT
# ...                                                  ...
# 13146           EASTERN UTILITIES ASSOCIATES 3RD QTR NET
# 13147               EC, U.S. PLAN HIGH-LEVEL TRADE TALKS
# 13148     BRITAIN BACKS U.S. STRIKE ON IRAN OIL PLATFORM
# 13149  SIMON AND SCHUSTER TO ACQUIRE WOODHEAD-FAULKNE...
# 13150     CCR VIDEO<CCCR.O> GETS OFFER ON TAKEOVER TALKS
#
#                                                     BODY
# 0      Showers continued throughout the week in the B...
# 1      The U.S. Agriculture Department reported the f...
# 2      Argentine grain board figures show crop regist...
# 3      Moody's Investors Service Inc said it lowered ...
# 4      Champion Products Inc said its board of direct...
# ...                                                  ...
# 13146  Shr 86 cts vs 74 cts     Net 11.1 mln vs 8.6 m...
# 13147  The European Community is willing to offer lim...
# 13148  British Foreign Secretary Sir Geoffrey Howe ba...
# 13149  SIMON AND SCHUSTER TO ACQUIRE WOODHEAD-FAULKNE...
# 13150  CCR Video Corp said it received an offer to en...
#
# [13151 rows x 4 columns]
